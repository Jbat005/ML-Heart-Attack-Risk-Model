# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## Build a model using training data that will predict the heart attack risk of the test set

# %%
# Importing the dataset
training_set = pd.read_csv('train.csv')
test_set = pd.read_csv('test.csv')
# Out:
#       Age     Sex  Cholesterol Blood Pressure  Heart Rate  Diabetes  \
# 0      33    Male          200         129/90          48         0
# 1      56  Female          262        159/105          46         1
# 2      19  Female          140        161/109          54         0
# 3      50  Female          163         120/62          53         0
# 4      89  Female          144        153/110          92         1
# ...   ...     ...          ...            ...         ...       ...
# 7005   29  Female          267        104/105          87         0
# 7006   83    Male          296         134/99          77         1
# 7007   54    Male          120         134/84         103         1
# 7008   42  Female          147         144/76          81         0
# 7009   61    Male          176         172/60          56         0
#
#       Family History  Smoking  Obesity  Alcohol Consumption  ...  \
# 0                  1        1        1                    1  ...
# 1                  0        1        0                    0  ...
# 2                  1        0        0                    1  ...
# 3                  1        1        1                    1  ...
# 4                  0        1        0                    1  ...
# ...              ...      ...      ...                  ...  ...
# 7005               0        0        1                    1  ...
# 7006               1        1        1                    0  ...
# 7007               1        1        1                    1  ...
# 7008               0        1        0                    1  ...
# 7009               1        1        0                    1  ...
#
#       Sedentary Hours Per Day  Income        BMI  Triglycerides  \
# 0                    0.138443  184066  30.449815             63
# 1                    0.369552  211755  34.973685            333
# 2                    8.646334  252203  30.554246            537
# 3                    1.107884  121954  35.390265            591
# 4                    1.337570  180121  39.575483            145
# ...                       ...     ...        ...            ...
# 7005                 6.806894  236184  27.521246            598
# 7006                 3.015648  264390  21.332449            465
# 7007                 4.825724  198358  37.465577            674
# 7008                 6.546390  202828  28.605789            623
# 7009                 6.651328   25823  22.057046            224
#
#       Physical Activity Days Per Week  Sleep Hours Per Day         Country  \
# 0                                   6                    7       Argentina
# 1                                   7                    8         Nigeria
# 2                                   2                   10        Thailand
# 3                                   0                    9           Spain
# 4                                   2                    5         Germany
# ...                               ...                  ...             ...
# 7005                                4                    5          France
# 7006                                4                    4  United Kingdom
# 7007                                6                    9        Colombia
# 7008                                7                   10           Spain
# 7009                                7                   10           India
#
#           Continent           Hemisphere  Heart Attack Risk
# 0     South America  Southern Hemisphere                  1
# 1            Africa  Northern Hemisphere                  1
# 2              Asia  Northern Hemisphere                  0
# 3            Europe  Southern Hemisphere                  1
# 4            Europe  Northern Hemisphere                  1
# ...             ...                  ...                ...
# 7005         Europe  Northern Hemisphere                  0
# 7006         Europe  Northern Hemisphere                  0
# 7007  South America  Northern Hemisphere                  0
# 7008         Europe  Southern Hemisphere                  1
# 7009           Asia  Northern Hemisphere                  0
#
# [7010 rows x 25 columns]

# %%
# Getting rid of the Patient ID column because it will not be used in the model
training_set = training_set.drop('Patient ID', axis=1)

# %%
# Formatting the data to be used in the model
gender_values = {"Male": 0, "Female": 1}
training_set['Sex'] = training_set['Sex'].map(gender_values)

# %%
# Split the 'blood pressure' column
training_set[['Systolic_BP', 'Diastolic_BP']] = training_set['Blood Pressure'].str.split('/', expand=True)

# Convert the new columns to numeric types
training_set['Systolic_BP'] = pd.to_numeric(training_set['Systolic_BP'])
training_set['Diastolic_BP'] = pd.to_numeric(training_set['Diastolic_BP'])
training_set = training_set.drop('Blood Pressure', axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/indexes/base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Blood Pressure'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Untitled-1.ipynb Cell 4 line 2
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W4sdW50aXRsZWQ%3D?line=0'>1</a> # Split the 'blood pressure' column
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W4sdW50aXRsZWQ%3D?line=1'>2</a> training_set[['Systolic_BP', 'Diastolic_BP']] = training_set['Blood Pressure'].str.split('/', expand=True)
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W4sdW50aXRsZWQ%3D?line=3'>4</a> # Convert the new columns to numeric types
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W4sdW50aXRsZWQ%3D?line=4'>5</a> training_set['Systolic_BP'] = pd.to_numeric(training_set['Systolic_BP'])
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/indexes/base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 'Blood Pressure'

# %%
training_set.head()
# Out:
#    Age  Sex  Cholesterol  Heart Rate  Diabetes  Family History  Smoking  \
# 0   33    0          200          48         0               1        1
# 1   56    1          262          46         1               0        1
# 2   19    1          140          54         0               1        0
# 3   50    1          163          53         0               1        1
# 4   89    1          144          92         1               0        1
#
#    Obesity  Alcohol Consumption  Exercise Hours Per Week  ...        BMI  \
# 0        1                    1                 7.807690  ...  30.449815
# 1        0                    0                17.297628  ...  34.973685
# 2        0                    1                 8.695288  ...  30.554246
# 3        1                    1                10.161587  ...  35.390265
# 4        0                    1                16.436787  ...  39.575483
#
#    Triglycerides  Physical Activity Days Per Week  Sleep Hours Per Day  \
# 0             63                                6                    7
# 1            333                                7                    8
# 2            537                                2                   10
# 3            591                                0                    9
# 4            145                                2                    5
#
#      Country      Continent           Hemisphere  Heart Attack Risk  \
# 0  Argentina  South America  Southern Hemisphere                  1
# 1    Nigeria         Africa  Northern Hemisphere                  1
# 2   Thailand           Asia  Northern Hemisphere                  0
# 3      Spain         Europe  Southern Hemisphere                  1
# 4    Germany         Europe  Northern Hemisphere                  1
#
#    Systolic_BP  Diastolic_BP
# 0          129            90
# 1          159           105
# 2          161           109
# 3          120            62
# 4          153           110
#
# [5 rows x 26 columns]

# %%
training_set.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Untitled-1.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W6sdW50aXRsZWQ%3D?line=0'>1</a> training_set.corr()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# -> 1889 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1890 if result.dtype is not dtype:
#    1891     result = np.array(result, dtype=dtype, copy=False)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/internals/managers.py:1656, in BlockManager.as_array(self, dtype, copy, na_value)
#    1654         arr.flags.writeable = False
#    1655 else:
# -> 1656     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1657     # The underlying data was copied within _interleave, so no need
#    1658     # to further copy if copy=True or setting na_value
#    1660 if na_value is lib.no_default:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/internals/managers.py:1715, in BlockManager._interleave(self, dtype, na_value)
#    1713     else:
#    1714         arr = blk.get_values(dtype)
# -> 1715     result[rl.indexer] = arr
#    1716     itemmask[rl.indexer] = 1
#    1718 if not itemmask.all():
#
# ValueError: could not convert string to float: 'Unhealthy'

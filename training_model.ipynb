# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
import os as os

# %% [markdown]
# ## Build a model using training data that will predict the heart attack risk of the test set

# %%
current_dir = os.getcwd()
current_dir

training_set = pd.read_csv(current_dir + '/Data/train.csv')
test_set = pd.read_csv(current_dir + '/Data/test.csv')

# %%
training_set.head()
# Out:
#   Patient ID  Age     Sex  Cholesterol Blood Pressure  Heart Rate  Diabetes  \
# 0    RDG0550   33    Male          200         129/90          48         0
# 1    NMA3851   56  Female          262        159/105          46         1
# 2    TUI5807   19  Female          140        161/109          54         0
# 3    YYT5016   50  Female          163         120/62          53         0
# 4    ZAC5937   89  Female          144        153/110          92         1
#
#    Family History  Smoking  Obesity  ...  Sedentary Hours Per Day  Income  \
# 0               1        1        1  ...                 0.138443  184066
# 1               0        1        0  ...                 0.369552  211755
# 2               1        0        0  ...                 8.646334  252203
# 3               1        1        1  ...                 1.107884  121954
# 4               0        1        0  ...                 1.337570  180121
#
#          BMI  Triglycerides  Physical Activity Days Per Week  \
# 0  30.449815             63                                6
# 1  34.973685            333                                7
# 2  30.554246            537                                2
# 3  35.390265            591                                0
# 4  39.575483            145                                2
#
#    Sleep Hours Per Day    Country      Continent           Hemisphere  \
# 0                    7  Argentina  South America  Southern Hemisphere
# 1                    8    Nigeria         Africa  Northern Hemisphere
# 2                   10   Thailand           Asia  Northern Hemisphere
# 3                    9      Spain         Europe  Southern Hemisphere
# 4                    5    Germany         Europe  Northern Hemisphere
#
#    Heart Attack Risk
# 0                  1
# 1                  1
# 2                  0
# 3                  1
# 4                  1
#
# [5 rows x 26 columns]

# %%
def data_clean(df):# Getting rid of the Patient ID column because it will not be used in the model
    cleaned_data = df.drop('Patient ID', axis=1)

    # Formatting the data to be used in the model
    gender_values = {"Male": 0, "Female": 1}
    cleaned_data['Sex'] = df['Sex'].map(gender_values)

    Diet_values= {"Unhealthy": 1, "Average": 2 ,"Healthy": 3}
    cleaned_data['Diet'] = df['Diet'].map(Diet_values)


    # Split the 'blood pressure' column
    cleaned_data[['Systolic_BP', 'Diastolic_BP']] = df['Blood Pressure'].str.split('/', expand=True)

    # Convert the new columns to numeric types
    cleaned_data['Systolic_BP'] = pd.to_numeric(cleaned_data['Systolic_BP'])
    cleaned_data['Diastolic_BP'] = pd.to_numeric(cleaned_data['Diastolic_BP'])
    cleaned_data = cleaned_data.drop('Blood Pressure', axis=1) # Has been replaced.

    # One-hot encode
    cleaned_data = pd.get_dummies(cleaned_data, columns=['Country', 'Continent', 'Hemisphere']).astype(int)

    return cleaned_data

# %%
clean_trained = data_clean(training_set)
clean_test = data_clean(test_set)

# %%
# Saving the file
clean_trained.to_csv(current_dir + '/Data/cleaned_training_set.csv')

# %%
features = clean_trained.drop('Heart Attack Risk', axis=1)
target = clean_trained['Heart Attack Risk']

# Train the model
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(features, target)

# Load the test data and apply the same preprocessing steps as the training data

# Apply the same preprocessing steps here...

# Separate the features in the test set
test_features = clean_test.drop('Heart Attack Risk', axis=1)

# Predict the heart attack risk on the test data
predictions = model.predict(test_features)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/jcarlito/Documents/GitHub/Heart-Attack-Risk-Analysis/training_model.ipynb Cell 8 line 1
#       <a href='vscode-notebook-cell:/Users/jcarlito/Documents/GitHub/Heart-Attack-Risk-Analysis/training_model.ipynb#X13sZmlsZQ%3D%3D?line=5'>6</a> model.fit(features, target)
#       <a href='vscode-notebook-cell:/Users/jcarlito/Documents/GitHub/Heart-Attack-Risk-Analysis/training_model.ipynb#X13sZmlsZQ%3D%3D?line=7'>8</a> # Load the test data and apply the same preprocessing steps as the training data
#       <a href='vscode-notebook-cell:/Users/jcarlito/Documents/GitHub/Heart-Attack-Risk-Analysis/training_model.ipynb#X13sZmlsZQ%3D%3D?line=8'>9</a>
#      <a href='vscode-notebook-cell:/Users/jcarlito/Documents/GitHub/Heart-Attack-Risk-Analysis/training_model.ipynb#X13sZmlsZQ%3D%3D?line=9'>10</a> # Apply the same preprocessing steps here...
#      <a href='vscode-notebook-cell:/Users/jcarlito/Documents/GitHub/Heart-Attack-Risk-Analysis/training_model.ipynb#X13sZmlsZQ%3D%3D?line=10'>11</a>
#      <a href='vscode-notebook-cell:/Users/jcarlito/Documents/GitHub/Heart-Attack-Risk-Analysis/training_model.ipynb#X13sZmlsZQ%3D%3D?line=11'>12</a> # Separate the features in the test set
# ---> <a href='vscode-notebook-cell:/Users/jcarlito/Documents/GitHub/Heart-Attack-Risk-Analysis/training_model.ipynb#X13sZmlsZQ%3D%3D?line=12'>13</a> test_features = clean_test.drop('Heart Attack Risk', axis=1)
#      <a href='vscode-notebook-cell:/Users/jcarlito/Documents/GitHub/Heart-Attack-Risk-Analysis/training_model.ipynb#X13sZmlsZQ%3D%3D?line=14'>15</a> # Predict the heart attack risk on the test data
#      <a href='vscode-notebook-cell:/Users/jcarlito/Documents/GitHub/Heart-Attack-Risk-Analysis/training_model.ipynb#X13sZmlsZQ%3D%3D?line=15'>16</a> predictions = model.predict(test_features)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
#    5351         errors=errors,
#    5352     )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/generic.py:4711, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709 for axis, labels in axes.items():
#    4710     if labels is not None:
# -> 4711         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4713 if inplace:
#    4714     self._update_inplace(obj)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/generic.py:4753, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4751         new_axis = axis.drop(labels, level=level, errors=errors)
#    4752     else:
# -> 4753         new_axis = axis.drop(labels, errors=errors)
#    4754     indexer = axis.get_indexer(new_axis)
#    4756 # Case for non-unique axis
#    4757 else:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/indexes/base.py:6992, in Index.drop(self, labels, errors)
#    6990 if mask.any():
#    6991     if errors != "ignore":
# -> 6992         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    6993     indexer = indexer[~mask]
#    6994 return self.delete(indexer)
#
# KeyError: "['Heart Attack Risk'] not found in axis"
